# %%
import torch
import torchvision
import math
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F

device=torch.device("cuda:0")

cfg=dict(
    T=1000, beta_start=1e-4,beta_end=0.02,
    img_size=32, channels=3,
    base_channels=128, channel_mults=(1,2,2,2), num_res_blocks=2, attn_resolution=16, dropout=0.1,
    batch_size=128, lr=2e-4, ema_decay=0.9999,
    sample_every=100, ckpt_every=100,
)
torch.manual_seed(0)
print(cfg)
print(torch.cuda.get_device_name())
print(torch.__version__)
# Out:
# {'T': 1000, 'beta_start': 0.0001, 'beta_end': 0.02, 'img_size': 32, 'channels': 3, 'base_channels': 128, 'channel_mults': (1, 2, 2, 2), 'num_res_blocks': 2, 'attn_resolution': 16, 'dropout': 0.1, 'batch_size': 128, 'lr': 0.0002, 'ema_decay': 0.9999, 'sample_every': 100, 'ckpt_every': 100}
# NVIDIA GeForce RTX 5090
# 2.11.0+cu128

# %%
from torch.utils.data import DataLoader


transforms=torchvision.transforms.Compose(
    [torchvision.transforms.RandomHorizontalFlip(), torchvision.transforms.ToTensor(), torchvision.transforms.Normalize(0.5,0.5)])

dataset=torchvision.datasets.CIFAR10(root="./data",train=True, download=True, transform=transforms)

train_dataloader=DataLoader(dataset, cfg["batch_size"], shuffle=True,num_workers=8, pin_memory=True, drop_last=True)

x0_demo, _=next(iter(train_dataloader))
# Out:
# /home/c504-5090-x2/miniconda3/lib/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
T = cfg["T"]
beta = torch.linspace(cfg["beta_start"], cfg["beta_end"], T, dtype=torch.float64)
alpha = 1.0 - beta
alpha_bar = torch.cumprod(alpha, dim=0)

sqrt_ab   = alpha_bar.sqrt().float().to(device)
sqrt_1mab = (1 - alpha_bar).sqrt().float().to(device)

print(f"ᾱ_1={alpha_bar[0]:.6f}  ᾱ_500={alpha_bar[499]:.4f}  ᾱ_1000={alpha_bar[-1]:.2e}")
# Out:
# ᾱ_1=0.999900  ᾱ_500=0.0786  ᾱ_1000=4.04e-05

# %%
def q_sample(x0, t, eps):
    """x0: (B,3,32,32) in [-1,1] | t: (B,) long on device | eps: randn like x0"""
    return (sqrt_ab[t].view(-1, 1, 1, 1) * x0 +
            sqrt_1mab[t].view(-1, 1, 1, 1) * eps)

# %%
def timestep_embed(t, dim):
    t=t.float()
    freqs=torch.exp(-math.log(10000)*torch.arange(dim//2, device=t.device)/(dim//2))
    outer_product=t[:,None]*freqs[None,:]
    output=torch.cat([torch.sin(outer_product), torch.cos(outer_product)], dim=-1)
    return output

class TimeEmbedding(nn.Module):
    def __init__(self, base_channels, time_dim):
        super().__init__()
        self.base_channels=base_channels
        self.time_dim=time_dim

        self.linear1=nn.Linear(base_channels, time_dim)
        self.silu=nn.SiLU(inplace=False)
        self.linear2=nn.Linear(time_dim,time_dim)
    def forward(self, t):
        t=timestep_embed(t, self.base_channels)
        t=self.linear1(t)
        t=self.silu(t)
        t=self.linear2(t)
        return t

# %%
class ResBlock(nn.Module):
    def __init__(self, time_dim, in_ch, out_ch,cfg):
        super().__init__()
        assert in_ch % 32 == 0 and out_ch % 32 == 0
        self.time_dim=time_dim
        self.out_ch=out_ch
        self.in_ch=in_ch

        self.norm1=nn.GroupNorm(32, in_ch)
        self.silu=nn.SiLU(inplace=False)
        self.conv1=nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1)
        self.linear_proj=nn.Linear(time_dim, 2*out_ch)
        self.norm2=nn.GroupNorm(32, out_ch)
        self.dropout=nn.Dropout(cfg["dropout"])
        self.conv2=nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1)
        if in_ch==out_ch:
            self.res=nn.Identity()
        else:
            self.res=nn.Conv2d(in_ch, out_ch, kernel_size=1)

    def forward(self, x, t_emb):
        h=self.norm1(x)
        h=self.silu(h)
        h=self.conv1(h)

        proj=self.silu(t_emb)
        proj=self.linear_proj(proj)
        scale, shift=proj.chunk(2, dim=1)

        scale=scale.view(-1, self.out_ch, 1 ,1)
        shift=shift.view(-1,self.out_ch, 1, 1)

        h=self.norm2(h)*(1+scale)+shift
        h=self.silu(h)
        h=self.dropout(h)
        h=self.conv2(h)

        return h+self.res(x)

# %%
class AttentionBlock(nn.Module):
    def __init__(self, channels, num_heads=None):
        super().__init__()
        if num_heads is None:
            assert channels % 64 == 0
            num_heads = channels // 64          # derive FIRST
        assert channels % num_heads == 0
        self.num_heads = num_heads              # store AFTER deriving
        self.head_dim = channels // num_heads
        self.norm = nn.GroupNorm(32, channels)
        self.proj = nn.Conv2d(channels, channels * 3, 1)
        self.out = nn.Conv2d(channels, channels, 1)

    def forward(self, x):
        h = self.norm(x)
        qkv = self.proj(h)
        q, k, v = qkv.chunk(3, dim=1)
        B, C, H, W = q.shape
        # split channels into heads (legal reshape: splits adjacent axis)...
        q = q.reshape(B, self.num_heads, self.head_dim, H * W).transpose(2, 3)
        k = k.reshape(B, self.num_heads, self.head_dim, H * W).transpose(2, 3)
        v = v.reshape(B, self.num_heads, self.head_dim, H * W).transpose(2, 3)
        # ...then transpose to (B, heads, seq, head_dim) for SDPA
        h = F.scaled_dot_product_attention(q, k, v)
        h = h.transpose(2, 3).reshape(B, C, H, W)   # exact inverse choreography
        h = self.out(h)
        return x + h

# %%
class Downsample(nn.Module):
  def __init__(self, channels):
    super().__init__()
    self.conv = nn.Conv2d(channels, channels, 3, stride=2, padding=1)
  def forward(self, x):
    return self.conv(x)

class Upsample(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv = nn.Conv2d(channels, channels, 3, padding=1)
    def forward(self, x):
        return self.conv(F.interpolate(x, scale_factor=2, mode="nearest"))

# %%
class DownPath(nn.Module):
  def __init__(self, in_channels, base_channels,  time_dim, dropout):
    super().__init__()
    self.skip_chs=[base_channels]*4+[base_channels*2]*8
    self.stem_conv=nn.Conv2d(in_channels, base_channels, kernel_size=3, stride=1, padding=1)
    self.resblock1=ResBlock(time_dim, base_channels, base_channels, cfg)
    self.resblock2=ResBlock(time_dim, base_channels, base_channels, cfg)
    self.downsample1=Downsample(base_channels)

    self.resblock3=ResBlock(time_dim, base_channels, base_channels*2, cfg)
    self.attn1=AttentionBlock(base_channels*2)

    self.resblock4=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)
    self.attn2=AttentionBlock(base_channels*2)

    self.downsample2=Downsample(base_channels*2)

    self.resblock5=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)
    self.resblock6=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)

    self.downsample3=Downsample(base_channels*2)

    self.resblock7=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)
    self.resblock8=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)
  def forward(self, x, t_emb):
    hs=[]
    h=self.stem_conv(x)
    hs.append(h)

    h=self.resblock1(h, t_emb)
    hs.append(h)
    h=self.resblock2(h, t_emb)
    hs.append(h)

    h=self.downsample1(h)
    hs.append(h)

    h=self.resblock3(h, t_emb)
    h=self.attn1(h)
    hs.append(h)

    h=self.resblock4(h,t_emb)
    h=self.attn2(h)
    hs.append(h)

    h=self.downsample2(h)
    hs.append(h)

    h=self.resblock5(h, t_emb)
    hs.append(h)
    h=self.resblock6(h, t_emb)
    hs.append(h)

    h=self.downsample3(h)
    hs.append(h)

    h=self.resblock7(h, t_emb)
    hs.append(h)
    h=self.resblock8(h, t_emb)
    hs.append(h)

    return h, hs

# %%
down = DownPath(3, 128, 512, 0.1).to(device)   # adjust to your final signature
x  = torch.randn(2, 3, 32, 32, device=device)
te = torch.randn(2, 512, device=device)
h, hs = down(x, te)
print(h.shape)                                  # (2, 256, 4, 4)
print(len(hs))                                  # 12
print([tuple(t.shape[1:]) for t in hs])         # channel/res of every push
print(down.skip_chs)
# Out:
# torch.Size([2, 256, 4, 4])
# 12
# [(128, 32, 32), (128, 32, 32), (128, 32, 32), (128, 16, 16), (256, 16, 16), (256, 16, 16), (256, 8, 8), (256, 8, 8), (256, 8, 8), (256, 4, 4), (256, 4, 4), (256, 4, 4)]
# [128, 128, 128, 128, 256, 256, 256, 256, 256, 256, 256, 256]

# %%
class UpPath(nn.Module):
  def __init__(self, base_channels, time_dim, dropout):
    super().__init__()
    self.resblock1=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.resblock2=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.resblock3=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.upsample1=Upsample(base_channels*2)

    self.resblock4=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.resblock5=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.resblock6=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.upsample2=Upsample(base_channels*2)

    self.resblock7=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.attn1=AttentionBlock(base_channels*2)

    self.resblock8=ResBlock(time_dim, base_channels*4, base_channels*2, cfg)
    self.attn2=AttentionBlock(base_channels*2)

    self.resblock9=ResBlock(time_dim, base_channels*3, base_channels*2, cfg)
    self.attn3=AttentionBlock(base_channels*2)

    self.upsample3=Upsample(base_channels*2)
    self.resblock10=ResBlock(time_dim, base_channels*3, base_channels, cfg)
    self.resblock11=ResBlock(time_dim, base_channels*2, base_channels, cfg)
    self.resblock12=ResBlock(time_dim, base_channels*2, base_channels, cfg)


  def forward(self, h, hs, t_emb):
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock1(h, t_emb)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock2(h, t_emb)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock3(h, t_emb)
    h=self.upsample1(h)

    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock4(h, t_emb)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock5(h, t_emb)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock6(h, t_emb)
    h=self.upsample2(h)

    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock7(h, t_emb)
    h=self.attn1(h)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock8(h, t_emb)
    h=self.attn2(h)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock9(h, t_emb)
    h=self.attn3(h)
    h=self.upsample3(h)

    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock10(h, t_emb)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock11(h, t_emb)
    h=torch.cat([h, hs.pop()], dim=1)
    h=self.resblock12(h, t_emb)

    assert len(hs)==0
    return h

# %%
up = UpPath(128, 512, 0.1).to(device)
h, hs = down(x, te)                    # reuse the verified DownPath outputs
out = up(h, hs, te)
print(out.shape)                       # (2, 128, 32, 32)
print(len(hs))
# Out:
# torch.Size([2, 128, 32, 32])
# 0

# %%
class Head(nn.Module):
  def __init__(self, base_channels):
    super().__init__()
    self.norm1=nn.GroupNorm(32, base_channels)
    self.silu=nn.SiLU(inplace=False)
    self.conv1=nn.Conv2d(base_channels, 3, kernel_size=3, padding=1)
    nn.init.zeros_(self.conv1.weight)
    nn.init.zeros_(self.conv1.bias)
  def forward(self, x):
    x=self.norm1(x)
    x=self.silu(x)
    x=self.conv1(x)
    return x

class Middle(nn.Module):
  def __init__(self, base_channels, time_dim, cfg):
    super().__init__()
    self.mid_block1=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)
    self.mid_attn=AttentionBlock(2*base_channels)
    self.mid_block2=ResBlock(time_dim, base_channels*2, base_channels*2, cfg)
  def forward(self, x, t_emb):
    x=self.mid_block1(x, t_emb)
    x=self.mid_attn(x)
    x=self.mid_block2(x, t_emb)
    return x

# %%
class UNet(nn.Module):
  def __init__(self, in_channels, base_channels, time_dim, dropout):
    super().__init__()
    self.time_embedding=TimeEmbedding(base_channels, time_dim)
    self.down=DownPath(in_channels, base_channels, time_dim, dropout)
    self.middle=Middle(base_channels, time_dim, cfg)
    self.up=UpPath(base_channels, time_dim, dropout)
    self.head=Head(base_channels)

  def forward(self, x, t):
    t_emb=self.time_embedding( t)
    h, hs=self.down(x, t_emb)
    h=self.middle(h, t_emb)
    h=self.up(h, hs, t_emb)
    h=self.head(h)
    return h

# %%
model = UNet(3, 128, 512, 0.1).to(device)

# (a) param count
n = sum(p.numel() for p in model.parameters())
print(f"{n/1e6:.2f}M")                          # expecting ~35-36M

# (b) forward shape
xb = torch.randn(8, 3, 32, 32, device=device)
tb = torch.randint(0, 1000, (8,), device=device)
out = model(xb, tb)
print(out.shape)                                # (8, 3, 32, 32)

# (c) zero-init head proof
print(out.abs().max().item())                   # exactly 0.0

# (d) full gradient sweep
model(xb, tb).sum().backward()   # fresh forward, since (c) was pre-backward... fine either way
missing = [n_ for n_, p in model.named_parameters() if p.grad is None]
print("no-grad params:", missing)
# Out:
# 38.31M
# torch.Size([8, 3, 32, 32])
# 0.0
# no-grad params: []

# %%
class EMA:
  def __init__(self, model, decay):
    self.decay=decay
    self.shadow={n: p.detach().clone() for n, p in model.named_parameters()}

  @torch.no_grad()
  def update(self, model):
    for n, p in model.named_parameters():
      self.shadow[n].mul_(self.decay).add_(p, alpha=1-self.decay)

  @torch.no_grad()
  def copy_to(self, model):
    for n, p in model.named_parameters():
      p.copy_(self.shadow[n])

# %%
model2 = UNet(3, 128, 512, 0.1).to(device)
ema = EMA(model2, 0.9999)
opt = torch.optim.Adam(model2.parameters(), lr=1e-3)
for _ in range(3):
    model2(xb, tb).sum().backward(); opt.step(); opt.zero_grad(); ema.update(model2)
name0 = next(iter(ema.shadow))
assert not torch.equal(ema.shadow[name0], dict(model2.named_parameters())[name0])

ema0 = EMA(model2, 0.0)
ema0.update(model2)
assert all(torch.equal(ema0.shadow[n], p) for n, p in model2.named_parameters())
print("EMA verified")
# Out:
# EMA verified

# %%
def loss_fn(model, x0):
  t=torch.randint(0, T, (x0.shape[0],), device=x0.device)
  eps=torch.randn_like(x0)
  x_t=q_sample(x0, t, eps)
  return F.mse_loss(model(x_t, t), eps)

# %%
model.eval()
with torch.no_grad():
    losses = [loss_fn(model, x0_demo.to(device)).item() for _ in range(10)]
import numpy as np
print(f"init loss: {np.mean(losses):.4f} ± {np.std(losses):.4f}")
# expect: 1.00 ± ~0.01 — the zero-init head predicts 0, so loss = E[ε²] = Var(N(0,1)) = 1
model.train()
# Out:
# init loss: 0.9992 ± 0.0027
# UNet(
#   (time_embedding): TimeEmbedding(
#     (linear1): Linear(in_features=128, out_features=512, bias=True)
#     (silu): SiLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (down): DownPath(
#     (stem_conv): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (resblock1): ResBlock(
#       (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (resblock2): ResBlock(
#       (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (downsample1): Downsample(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (resblock3): ResBlock(
#       (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn1): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock4): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (attn2): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (downsample2): Downsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (resblock5): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (resblock6): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (downsample3): Downsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (resblock7): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (resblock8): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#   )
#   (middle): Middle(
#     (mid_block1): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (mid_attn): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mid_block2): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#   )
#   (up): UpPath(
#     (resblock1): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock2): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock3): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (upsample1): Upsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (resblock4): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock5): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock6): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (upsample2): Upsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (resblock7): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn1): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock8): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn2): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock9): ResBlock(
#       (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn3): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (upsample3): Upsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (resblock10): ResBlock(
#       (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock11): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock12): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (head): Head(
#     (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#     (silu): SiLU()
#     (conv1): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
ab=alpha_bar.float().to(device)

ab_prev=torch.cat([torch.ones(1, device=device), ab[:-1]])

beta_d=beta.float().to(device)

alpha_d=alpha.float().to(device)


beta_tilde=(1-ab_prev)/(1-ab)*beta_d

sigma=torch.sqrt(beta_tilde)

coef_x0=torch.sqrt(ab_prev)*beta_d / (1 - ab)

coef_xt = torch.sqrt(alpha_d) * (1 - ab_prev) / (1 - ab)

@torch.no_grad()

def sample(model, n_samples, x=None):
    if x is None:
        x = torch.randn(n_samples, 3, 32, 32, device=device)
    for t in reversed(range(T)):
        t_batch=torch.full((n_samples,),t,device=device, dtype=torch.long)
        eps_hat=model(x, t_batch)
        x0_hat = (x - torch.sqrt(1 - ab[t]) * eps_hat) / torch.sqrt(ab[t])
        x0_hat = x0_hat.clamp(-1, 1)
        mean = coef_x0[t] * x0_hat + coef_xt[t] * x

        if t > 0:
          z = torch.randn_like(x)
          x = mean + sigma[t] * z
    
        else:
          x = mean
    return x
s = sample(model, 8)
print(torch.isfinite(s).all().item())          # True
print(s.min().item(), s.max().item())
# Out:
# True
# -0.9998340606689453 0.9998340606689453

# %%
# freeze one batch
x_fixed = x0_demo[:128].to(device)

# fresh everything
gate_model = UNet(3, 128, 512, 0.1).to(device)
gate_ema   = EMA(gate_model, cfg["ema_decay"])
gate_opt   = torch.optim.Adam(gate_model.parameters(), lr=cfg["lr"])

gate_model.train()
for step in range(5000):
    loss = loss_fn(gate_model, x_fixed)
    gate_opt.zero_grad(); loss.backward(); gate_opt.step()
    gate_ema.update(gate_model)
    if step % 500 == 0:
        print(f"step {step}: loss {loss.item():.4f}")
# Out:
# step 0: loss 0.9988
# step 500: loss 0.0183
# step 1000: loss 0.0152
# step 1500: loss 0.0148
# step 2000: loss 0.0082
# step 2500: loss 0.0111
# step 3000: loss 0.0061
# step 3500: loss 0.0076
# step 4000: loss 0.0089
# step 4500: loss 0.0087

# %%
eval_model = UNet(3, 128, 512, 0.1).to(device)
gate_ema.copy_to(eval_model)
eval_model.eval()

samples = sample(eval_model, 8)

import matplotlib.pyplot as plt
fig, axes = plt.subplots(2, 8, figsize=(16, 4))
for i in range(8):
    axes[0, i].imshow(((x_fixed[i].cpu() + 1) / 2).permute(1, 2, 0)); axes[0, i].axis("off")
    axes[1, i].imshow(((samples[i].cpu().clamp(-1, 1) + 1) / 2).permute(1, 2, 0)); axes[1, i].axis("off")
axes[0, 0].set_title("originals (top) vs samples (bottom)", loc="left")
plt.show()

# %%
# 1. did training actually reduce the loss?
print(loss_fn(gate_model, x_fixed).item())     # should be ~0.0X if trained

# 2. did copy_to actually change eval_model's weights?
before = [p.clone() for p in eval_model.parameters()]
gate_ema.copy_to(eval_model)
changed = any(not torch.equal(b, p) for b, p in zip(before, eval_model.parameters()))
print("copy_to changed weights:", changed)

# 3. sanity: sample from the TRAINED model directly, bypassing EMA+eval
gate_model.eval()
s2 = sample(gate_model, 8)
gate_model.train()
# plot s2 — if THIS shows structure, the bug is in the EMA/eval handoff, not training or sampler
# Out:
# 0.00878116488456726
# copy_to changed weights: False
# UNet(
#   (time_embedding): TimeEmbedding(
#     (linear1): Linear(in_features=128, out_features=512, bias=True)
#     (silu): SiLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (down): DownPath(
#     (stem_conv): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (resblock1): ResBlock(
#       (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (resblock2): ResBlock(
#       (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (downsample1): Downsample(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (resblock3): ResBlock(
#       (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn1): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock4): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (attn2): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (downsample2): Downsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (resblock5): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (resblock6): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (downsample3): Downsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (resblock7): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (resblock8): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#   )
#   (middle): Middle(
#     (mid_block1): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#     (mid_attn): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mid_block2): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Identity()
#     )
#   )
#   (up): UpPath(
#     (resblock1): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock2): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock3): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (upsample1): Upsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (resblock4): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock5): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock6): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (upsample2): Upsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (resblock7): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn1): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock8): ResBlock(
#       (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn2): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock9): ResBlock(
#       (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=512, bias=True)
#       (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (attn3): AttentionBlock(
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (proj): Conv2d(256, 768, kernel_size=(1, 1), stride=(1, 1))
#       (out): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (upsample3): Upsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (resblock10): ResBlock(
#       (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock11): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (resblock12): ResBlock(
#       (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#       (silu): SiLU()
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (linear_proj): Linear(in_features=512, out_features=256, bias=True)
#       (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (res): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (head): Head(
#     (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#     (silu): SiLU()
#     (conv1): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
# compare shadow against the TRAINED model's params
p_trained = dict(gate_model.named_parameters())
name0 = next(iter(gate_ema.shadow))
print("shadow vs trained:", (gate_ema.shadow[name0] - p_trained[name0]).abs().max().item())
# Out:
# shadow vs trained: 0.035749807953834534

# %%
gate_model.eval()
s2 = sample(gate_model, 8)
gate_model.train()

fig, axes = plt.subplots(1, 8, figsize=(16, 2))
for i in range(8):
    axes[i].imshow(((s2[i].cpu().clamp(-1,1)+1)/2).permute(1,2,0)); axes[i].axis("off")
plt.show()

# %%
def sample_ema(model, ema, n, x=None):
    backup = {n_: p.detach().clone() for n_, p in model.named_parameters()}
    ema.copy_to(model); model.eval()
    imgs = sample(model, n)
    model.train()
    with torch.no_grad():
        for n_, p in model.named_parameters(): p.copy_(backup[n_])
    return imgs

# %%
#training loop for CIFAR finally
import os
os.makedirs("samples", exist_ok=True)
os.makedirs("checkpoints", exist_ok=True)

print(os.listdir("."))   # confirm both appear
import os

model=UNet(3,128,512,0.1).to(device)
ema=EMA(model, cfg["ema_decay"])
opt=torch.optim.Adam(model.parameters(), lr=cfg["lr"])
total_steps=300

torch.manual_seed(1234)
fixed_noise=torch.randn(64,3,32,32, device=device)


step=0
model.train()
while step<total_steps:
    for x0, _ in train_dataloader:
        x0=x0.to(device)
        loss=loss_fn(model, x0)
        opt.zero_grad()
        loss.backward()
        opt.step()
        ema.update(model)
        step+=1

        if step%100==0:
            print(f"step {step}: {loss.item():.4f}")
        if step%cfg["sample_every"]==0:
            imgs = sample_ema(model, ema, 64, x=fixed_noise)   
            grid = torchvision.utils.make_grid((imgs.clamp(-1,1)+1)/2, nrow=8)
            torchvision.utils.save_image(grid, f"samples/step_{step}.png")
        if step % cfg["ckpt_every"]==0:
            torch.save({"step": step, "model": model.state_dict(),
                "ema": ema.shadow, "opt": opt.state_dict()},
               f"checkpoints/step_{step}.pt")
        if step>=total_steps:
            break
torch.save({
    "step": step,
    "model": model.state_dict(),
    "ema": ema.shadow,                    # the dict of shadow tensors
    "opt": opt.state_dict(),
}, f"checkpoints/step_{step}.pt")
# Out:
# ['.gphoto', '.nv', 'aibek', 'Public', '.ipynb_checkpoints', '.gnupg', 'Pictures', '.lesshst', '.vscode-remote-containers', '.vscode', 'DDPM.ipynb', '.mne', 'my_ip.txt', 'mne_data', 'miniconda3', 'data', '.tilelang', '.sudo_as_admin_successful', '.copilot', '.local', '.triton', '.codex', '.anaconda', 'samples', 'talas', 'Videos', '.dotnet', '.jupyter', '.conda', '.kaggle', '.bash_logout', '.ssh', 'Desktop', '.pki', '.idlerc', 'Music', '.python_history', '.profile', '.vscode-server', 'Templates', 'snap', '.vscode-shared', '.cache', 'Downloads', '.wget-hsts', 'Documents', '.config', 'kaz_punct', '.ipython', 'checkpoints', '.bashrc', '.claude.json', '.bash_history', '.ollama', '.claude']
# step 100: 0.0529
# step 200: 0.0376
# step 300: 0.0322

# %%
import os
print(os.getcwd())                    # where the kernel is running = where folders were made
print(os.listdir("samples"))          # the PNG filenames
print(os.listdir("checkpoints"))      # the .pt filenames
# Out:
# /home/c504-5090-x2
# ['step_100.png', 'step_300.png', 'step_200.png']
# ['step_300.pt', 'step_100.pt', 'step_200.pt']
